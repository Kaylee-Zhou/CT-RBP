# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score, average_precision_score, confusion_matrix, roc_curve, precision_recall_curve, matthews_corrcoef
import matplotlib.pyplot as plt
import seaborn as sns
import os
from collections import Counter
import json
import pickle
import random
import warnings

warnings.filterwarnings("ignore", category=RuntimeWarning, 
                        message="invalid value encountered in double_scalars",
                        module="sklearn.metrics._classification")

print("All libraries have been successfully imported.")
# Out:
# All libraries have been successfully imported.

# %%
# Set the random seed
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)
    print(f"The random seed has been set to: {seed}")

set_seed(42)
# Out:
# The random seed has been set to: 42

# %%
# Configure the parameters
class FixedConfig:
    max_length = 101
    batch_size = 32
    data_path = 'HNRNPC'
    
    # Model parameters
    d_model = 128
    nhead = 8
    num_layers = 3
    dropout = 0.3
    structure_embed_dim = 16
    pairing_embed_dim = 16
    conv_out_channels = 64
    conv_kernel_size = 5
    
    # Training parameters
    num_epochs = 125
    learning_rate = 8e-5
    weight_decay = 1e-4
    patience = 15
    gradient_clip = 1.0
    
    # Class balance
    focal_alpha = 0.75
    focal_gamma = 2.0
    
    # Classifier
    classifier_hidden_dims = [64, 32]
    
    # Output path
    model_save_path = f"{data_path}/Output/model.pth"
    vocab_save_path = f"{data_path}/Output/vocab.pkl"
    metrics_save_path = f"{data_path}/Output/metrics.csv"
    plots_save_dir = f"{data_path}/Output/plots"
    
    print(f"Parameter settings have been successfully completed.")

config = FixedConfig()
# Out:
# Parameter settings have been successfully completed.

# %%
# Methods definition
# Enhance the dataset
class EnhancedRNADataset(Dataset):
    def __init__(self, dataframe, kmer_vocab=None, max_length=101, augment=False):
        self.data = dataframe
        self.max_length = max_length
        self.augment = augment
        
        if kmer_vocab is None:
            self.kmer_vocab = self._build_vocab()
        else:
            self.kmer_vocab = kmer_vocab
            
        self.pad_token = '<PAD>'
        self.unk_token = '<UNK>'
        if self.pad_token not in self.kmer_vocab:
            self.kmer_vocab[self.pad_token] = len(self.kmer_vocab)
        if self.unk_token not in self.kmer_vocab:
            self.kmer_vocab[self.unk_token] = len(self.kmer_vocab)
            
        self.vocab_size = len(self.kmer_vocab)
        
    def _build_vocab(self):
        all_kmers = []
        for seq in self.data['sequence']:
            kmers = seq.split()
            all_kmers.extend(kmers)
        kmer_counts = Counter(all_kmers)
        return {kmer: idx for idx, (kmer, _) in enumerate(kmer_counts.most_common())}
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        
        # Sequence processing
        sequence = row['sequence']
        kmers = sequence.split()
        seq_indices = [self.kmer_vocab.get(kmer, self.kmer_vocab[self.unk_token]) 
                      for kmer in kmers[:self.max_length]]
        
        if len(seq_indices) < self.max_length:
            seq_indices = seq_indices + [self.kmer_vocab[self.pad_token]] * (self.max_length - len(seq_indices))
        else:
            seq_indices = seq_indices[:self.max_length]
            
        # Secondary structure characteristics processing
        structure = eval(row['structure']) if isinstance(row['structure'], str) else row['structure']
        if len(structure) < self.max_length:
            structure = structure + [0] * (self.max_length - len(structure))
        else:
            structure = structure[:self.max_length]
            
        # Base pairing probability processing
        pairing_prob = eval(row['pairing_probabilities']) if isinstance(row['pairing_probabilities'], str) else row['pairing_probabilities']
        if len(pairing_prob) < self.max_length:
            pairing_prob = pairing_prob + [0.0] * (self.max_length - len(pairing_prob))
        else:
            pairing_prob = pairing_prob[:self.max_length]
            
        label = row['label']
        
        # Convert to tensor
        sequence_tensor = torch.tensor(seq_indices, dtype=torch.long)
        structure_tensor = torch.tensor(structure, dtype=torch.long)
        pairing_prob_tensor = torch.tensor(pairing_prob, dtype=torch.float)
        label_tensor = torch.tensor(label, dtype=torch.float)
        
        return {
            'sequence': sequence_tensor,
            'structure': structure_tensor,
            'pairing_prob': pairing_prob_tensor,
            'label': label_tensor
        }

# Position encoding
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=100):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:x.size(0), :]

# Model
class RNAModel(nn.Module):
    def __init__(self, vocab_size):
        super(RNAModel, self).__init__()
        
        # Embedding layer
        self.sequence_embedding = nn.Embedding(vocab_size, config.d_model)
        self.structure_embedding = nn.Embedding(3, config.structure_embed_dim)
        self.pairing_prob_projection = nn.Linear(1, config.pairing_embed_dim)
        
        # Convolutional layer
        conv_input_dim = config.d_model + config.structure_embed_dim + config.pairing_embed_dim
        self.conv1 = nn.Conv1d(conv_input_dim, config.conv_out_channels, 
                              kernel_size=config.conv_kernel_size, padding=config.conv_kernel_size//2)
        self.conv2 = nn.Conv1d(config.conv_out_channels, config.conv_out_channels*2, 
                              kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(config.conv_out_channels)
        self.bn2 = nn.BatchNorm1d(config.conv_out_channels*2)
        self.conv_activation = nn.ReLU()
        self.conv_dropout = nn.Dropout(config.dropout)
        
        # Transformer encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=config.conv_out_channels*2,
            nhead=config.nhead,
            dim_feedforward=config.conv_out_channels*4,
            dropout=config.dropout
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, config.num_layers)
        self.pos_encoding = PositionalEncoding(config.conv_out_channels*2, config.max_length)
        
        # Classifier
        classifier_layers = []
        input_dim = config.conv_out_channels*2
        
        for hidden_dim in config.classifier_hidden_dims:
            classifier_layers.extend([
                nn.Linear(input_dim, hidden_dim),
                nn.BatchNorm1d(hidden_dim),
                nn.ReLU(),
                nn.Dropout(config.dropout)
            ])
            input_dim = hidden_dim
            
        classifier_layers.append(nn.Linear(input_dim, 1))
        self.classifier = nn.Sequential(*classifier_layers)
        
        # Initialize weights
        self._initialize_weights()
        
    def _initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.Embedding):
                nn.init.normal_(module.weight, mean=0, std=0.1)
            elif isinstance(module, nn.Conv1d):
                nn.init.kaiming_normal_(module.weight, mode='fan_in', nonlinearity='relu')
        
    def forward(self, sequence, structure, pairing_prob):
        batch_size = sequence.size(0)
        
        # Embedding
        seq_emb = self.sequence_embedding(sequence)
        structure_emb = self.structure_embedding(structure)
        pairing_emb = self.pairing_prob_projection(pairing_prob.unsqueeze(-1))
        
        # Merge features
        combined_emb = torch.cat([seq_emb, structure_emb, pairing_emb], dim=-1)
        
        # Convolutional layer
        conv_input = combined_emb.transpose(1, 2)
        conv1_out = self.conv1(conv_input)
        conv1_out = self.bn1(conv1_out)
        conv1_out = self.conv_activation(conv1_out)
        conv1_out = self.conv_dropout(conv1_out)
        
        conv2_out = self.conv2(conv1_out)
        conv2_out = self.bn2(conv2_out)
        conv2_out = self.conv_activation(conv2_out)
        conv2_out = self.conv_dropout(conv2_out)
        
        # Transformer
        # The input shape should be (seq_len, batch_size, d_model)
        transformer_input = conv2_out.transpose(1, 2)  # (batch_size, seq_len, d_model)
        transformer_input = transformer_input.transpose(0, 1)  # (seq_len, batch_size, d_model)
        transformer_input = self.pos_encoding(transformer_input)  # (seq_len, batch_size, d_model)
        transformer_out = self.transformer_encoder(transformer_input)  # (seq_len, batch_size, d_model)
        transformer_out = transformer_out.transpose(0, 1)  # (batch_size, seq_len, d_model)
        
        # Global pooling
        pooled = transformer_out.mean(dim=1)  # (batch_size, d_model)
        
        # Classification
        logits = self.classifier(pooled)
        return logits.squeeze()
    
# Focal Loss
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.75, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        BCE_loss = nn.functional.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss
        
        if self.reduction == 'mean':
            return torch.mean(F_loss)
        elif self.reduction == 'sum':
            return torch.sum(F_loss)
        else:
            return F_loss    

# Calculate all metrics
def calculate_all_metrics(y_true, y_pred, threshold=0.5):
    # Binary predictions
    y_pred_binary = (y_pred > threshold).astype(int)
    
    # Confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred_binary).ravel()
    
    # Basic metrics
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0  # Recall
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1 = 2 * precision * sensitivity / (precision + sensitivity) if (precision + sensitivity) > 0 else 0
    
    # MCC
    mcc = matthews_corrcoef(y_true, y_pred_binary)
    
    # AUC metrics
    auroc = roc_auc_score(y_true, y_pred)
    auprc = average_precision_score(y_true, y_pred)
    
    metrics = {
        'Accuracy': accuracy,
        'Precision': precision,
        'Sensitivity': sensitivity,
        'Specificity': specificity,
        'F1-Score': f1,
        'MCC': mcc,
        'AUROC': auroc,
        'AUPRC': auprc,
        'TP': tp,
        'TN': tn,
        'FP': fp,
        'FN': fn,
        'Threshold': threshold
    }
    
    return metrics

# Plotting functions
def plot_training_curves(train_losses, val_losses, val_aurocs, val_auprcs, save_path):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss curve
    epochs = range(1, len(train_losses) + 1)
    axes[0, 0].plot(epochs, train_losses, 'b-', label='Train Loss')
    axes[0, 0].plot(epochs, val_losses, 'r-', label='Evaluate Loss')
    axes[0, 0].set_title('Train and Evaluate Loss')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    axes[0, 0].grid(True)
    
    # AUROC curve
    axes[0, 1].plot(epochs, val_aurocs, 'g-', label='Evaluate AUROC')
    axes[0, 1].set_title('Evaluate AUROC')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('AUROC')
    axes[0, 1].legend()
    axes[0, 1].grid(True)
    
    # AUPRC curve
    axes[1, 0].plot(epochs, val_auprcs, 'purple', label='Evaluate AUPRC')
    axes[1, 0].set_title('Evaluate AUPRC')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('AUPRC')
    axes[1, 0].legend()
    axes[1, 0].grid(True)
    
    # Learning rate curve (if available)
    if hasattr(config, 'learning_rates'):
        axes[1, 1].plot(epochs, config.learning_rates[:len(epochs)], 'orange', label='Learning Rate')
        axes[1, 1].set_title('Learning Rate')
        axes[1, 1].set_xlabel('Epochs')
        axes[1, 1].set_ylabel('Learning Rate')
        axes[1, 1].legend()
        axes[1, 1].grid(True)
    
    plt.tight_layout()
    plt.savefig(save_path, dpi=600, bbox_inches='tight')
    plt.show()  # Display the image
    plt.close()

def plot_roc_curve(y_true, y_pred, save_path):
    """Plot ROC curve"""
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    auroc = roc_auc_score(y_true, y_pred)
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {auroc:.4f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.savefig(save_path, dpi=600, bbox_inches='tight')
    plt.show()  # Display the image
    plt.close()

def plot_pr_curve(y_true, y_pred, save_path):
    """Plot Precision-Recall curve"""
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    auprc = average_precision_score(y_true, y_pred)
    
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, color='blue', lw=2, label=f'PR curve (AUPRC = {auprc:.4f})')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend(loc="upper right")
    plt.grid(True)
    plt.savefig(save_path, dpi=600, bbox_inches='tight')
    plt.show()  # Display the image
    plt.close()

def plot_confusion_matrix(y_true, y_pred, threshold=0.5, save_path=None):
    """Plot confusion matrix"""
    y_pred_binary = (y_pred > threshold).astype(int)
    cm = confusion_matrix(y_true, y_pred_binary)
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Predicted Negative', 'Predicted Positive'],
                yticklabels=['Actual Negative', 'Actual Positive'])
    plt.title(f'Confusion Matrix (Threshold = {threshold:.2f})')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    
    if save_path:
        plt.savefig(save_path, dpi=600, bbox_inches='tight')
        plt.show()  # Display the image
        plt.close()
    else:
        plt.show()

def plot_probability_distribution(y_true, y_pred, threshold, save_path):
    """Plot probability distribution for positive and negative samples"""
    positive_probs = y_pred[y_true == 1]
    negative_probs = y_pred[y_true == 0]
    
    plt.figure(figsize=(10, 6))
    plt.hist(positive_probs, bins=50, alpha=0.7, label='Positive Samples', color='green')
    plt.hist(negative_probs, bins=50, alpha=0.7, label='Negative Samples', color='red')
    plt.axvline(x=threshold, color='black', linestyle='--', linewidth=2, 
                label=f'Threshold = {threshold:.2f}')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Frequency')
    plt.title('Predicted Probability Distribution')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.savefig(save_path, dpi=600, bbox_inches='tight')
    plt.show()  # Display the image
    plt.close()

# Training function
def train(model, train_loader, val_loader, device):
    # Use Focal Loss
    criterion = FocalLoss(alpha=config.focal_alpha, gamma=config.focal_gamma)
    
    # Optimizer
    optimizer = optim.AdamW(
        model.parameters(),
        lr=config.learning_rate,
        weight_decay=config.weight_decay,
        betas=(0.9, 0.999)
    )
    
    # Learning rate scheduling - Using cosine annealing
    scheduler = optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=config.num_epochs, eta_min=1e-7
    )
    
    train_losses = []
    val_losses = []
    val_aurocs = []
    val_auprcs = []
    learning_rates = []
    best_val_auc = 0.0
    patience_counter = 0
    
    print("Training start...")
    
    for epoch in range(config.num_epochs):
        # Train phase
        model.train()
        train_loss = 0.0
        batch_count = 0
        
        all_preds = []
        all_labels = []
        
        for batch in train_loader:
            sequence = batch['sequence'].to(device)
            structure = batch['structure'].to(device)
            pairing_prob = batch['pairing_prob'].to(device)
            labels = batch['label'].to(device)
            
            optimizer.zero_grad()
            logits = model(sequence, structure, pairing_prob)
            loss = criterion(logits, labels)
            loss.backward()
            
            torch.nn.utils.clip_grad_norm_(model.parameters(), config.gradient_clip)
            optimizer.step()
            
            train_loss += loss.item()
            batch_count += 1
            
            # Collect predictions
            with torch.no_grad():
                preds = torch.sigmoid(logits)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        
        train_loss /= batch_count
        all_preds = np.array(all_preds)
        all_labels = np.array(all_labels)
        
        # Evaluate phase
        model.eval()
        val_loss = 0.0
        val_preds = []
        val_true = []
        
        with torch.no_grad():
            for batch in val_loader:
                sequence = batch['sequence'].to(device)
                structure = batch['structure'].to(device)
                pairing_prob = batch['pairing_prob'].to(device)
                labels = batch['label'].to(device)
                
                logits = model(sequence, structure, pairing_prob)
                loss = criterion(logits, labels)
                val_loss += loss.item()
                
                preds = torch.sigmoid(logits)
                val_preds.extend(preds.cpu().numpy())
                val_true.extend(labels.cpu().numpy())
        
        val_loss /= len(val_loader)
        val_preds = np.array(val_preds)
        val_true = np.array(val_true)
        
        # Calculate indicators
        try:
            val_auc = roc_auc_score(val_true, val_preds)
            val_auprc = average_precision_score(val_true, val_preds)
        except:
            val_auc = 0.5
            val_auprc = 0.5
            
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_aurocs.append(val_auc)
        val_auprcs.append(val_auprc)
        learning_rates.append(optimizer.param_groups[0]['lr'])
        
        # Analyze the prediction distribution
        train_pred_ratio = np.mean(all_preds > 0.5)
        val_pred_ratio = np.mean(val_preds > 0.5)
        train_true_ratio = np.mean(all_labels)
        val_true_ratio = np.mean(val_true)
        
        current_lr = optimizer.param_groups[0]['lr']
        
        print(f'Epoch [{epoch+1}/{config.num_epochs}]')
        print(f'  Train loss: {train_loss:.4f}, Evaluate loss: {val_loss:.4f}')
        print(f'  Evaluate AUROC: {val_auc:.4f}, Evaluate AUPRC: {val_auprc:.4f}')
        print(f'  Learning rate: {current_lr:.2e}')
        print(f'  Train set - Real:    {train_true_ratio:.3f}, Predict: {train_pred_ratio:.3f}')
        print(f'  Evaluate set - Real: {val_true_ratio:.3f}, Predict: {val_pred_ratio:.3f}')
        
        # Early stop
        if val_auc > best_val_auc:
            best_val_auc = val_auc
            patience_counter = 0
            torch.save(model.state_dict(), config.model_save_path)
            print(f'  Save the best model, AUROC: {val_auc:.4f}')
        else:
            patience_counter += 1
            
        # Update learning rate
        scheduler.step()
        
        if patience_counter >= config.patience:
            print(f'\nEarly stopping occurred at the {epoch + 1}th epoch.')
            break
            
        print('-' * 50)
    
    # Store learning rates for plotting
    config.learning_rates = learning_rates
    
    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'val_aurocs': val_aurocs,
        'val_auprcs': val_auprcs,
        'best_val_auc': best_val_auc
    }

# Test function
def comprehensive_test(model, test_loader, device):
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for batch in test_loader:
            sequence = batch['sequence'].to(device)
            structure = batch['structure'].to(device)
            pairing_prob = batch['pairing_prob'].to(device)
            labels = batch['label'].to(device)
            
            logits = model(sequence, structure, pairing_prob)
            preds = torch.sigmoid(logits)
            
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    
    # Search for multiple thresholds
    thresholds = np.arange(0.1, 0.9, 0.05)
    results = []
    
    for threshold in thresholds:
        metrics = calculate_all_metrics(all_labels, all_preds, threshold)
        results.append(metrics)
    
    # Select the optimal threshold based on F1 score
    best_result = max(results, key=lambda x: x['Accuracy'])
    
    print(f"\nPerformance of the test set (threshold={best_result['Threshold']:.2f}):")
    print(f"AUROC:       {best_result['AUROC']:.4f}")
    print(f"AUPRC:       {best_result['AUPRC']:.4f}")
    print(f"Accuracy:    {best_result['Accuracy']:.4f}")
    print(f"Precision:   {best_result['Precision']:.4f}")
    print(f"Sensitivity: {best_result['Sensitivity']:.4f}")
    print(f"F1-Score:    {best_result['F1-Score']:.4f}")
    print(f"Specificity: {best_result['Specificity']:.4f}")
    print(f"MCC:         {best_result['MCC']:.4f}")
    
    
    # Analyze prediction distribution 
    pred_ratio = np.mean(all_preds > 0.5)
    true_ratio = np.mean(all_labels)

    return {
        'all_metrics': best_result,
        'all_results': results,
        'predictions': all_preds,
        'labels': all_labels,
        'best_threshold': best_result['Threshold']
    }

# Save metrics to CSV
def save_metrics_to_csv(metrics, save_path):
    """Save metrics to CSV file"""
    df = pd.DataFrame([metrics])
    df.to_csv(save_path, index=False)
    print(f"Metrics saved to {save_path}")

print(f"Methods definition completed")
# Out:
# Methods definition completed

# %%
# Preparations before train
# Data loading
print("Data loading...")
train_df = pd.read_csv(f'{config.data_path}/train.tsv', sep='\t')
eval_df = pd.read_csv(f'{config.data_path}/eval.tsv', sep='\t')
test_df = pd.read_csv(f'{config.data_path}/test.tsv', sep='\t')

print(f"Train set:    {len(train_df)}, Positive sample ratio: {train_df['label'].mean():.3f}")
print(f"Evaluate set: {len(eval_df)}, Positive sample ratio: {eval_df['label'].mean():.3f}")
print(f"Test set:     {len(test_df)}, Positive sample ratio: {test_df['label'].mean():.3f}")

# Create datasets
train_dataset = EnhancedRNADataset(train_df, max_length=config.max_length)
eval_dataset = EnhancedRNADataset(eval_df, kmer_vocab=train_dataset.kmer_vocab, max_length=config.max_length)
test_dataset = EnhancedRNADataset(test_df, kmer_vocab=train_dataset.kmer_vocab, max_length=config.max_length)

# Save the vocabulary list
os.makedirs(config.plots_save_dir, exist_ok=True)
with open(config.vocab_save_path, 'wb') as f:
    pickle.dump(train_dataset.kmer_vocab, f)
            
# Data loaders
train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True)
eval_loader = DataLoader(eval_dataset, batch_size=config.batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=config.batch_size, shuffle=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device used: {device}")
# Out:
# Data loading...
# Train set:    2400, Positive sample ratio: 0.492
# Evaluate set: 300, Positive sample ratio: 0.543
# Test set:     300, Positive sample ratio: 0.523
# Device used: cuda

# %%
# Train the model
print("Start training the model...")
model = RNAModel(vocab_size=train_dataset.vocab_size).to(device)

results = train(model, train_loader, eval_loader, device)
print(f"\nBest evaluate AUROC: {results['best_val_auc']:.4f}")
# Out:
# Start training the model...
# Training start...
# Epoch [1/125]
#   Train loss: 0.2121, Evaluate loss: 0.8298
#   Evaluate AUROC: 0.5866, Evaluate AUPRC: 0.6249
#   Learning rate: 8.00e-05
#   Train set - Real:    0.492, Predict: 0.595
#   Evaluate set - Real: 0.543, Predict: 0.997
#   Save the best model, AUROC: 0.5866
# --------------------------------------------------
# Epoch [2/125]
#   Train loss: 0.1830, Evaluate loss: 0.3456
#   Evaluate AUROC: 0.7097, Evaluate AUPRC: 0.7489
#   Learning rate: 8.00e-05
#   Train set - Real:    0.492, Predict: 0.583
#   Evaluate set - Real: 0.543, Predict: 0.947
#   Save the best model, AUROC: 0.7097
# --------------------------------------------------
# Epoch [3/125]
#   Train loss: 0.1632, Evaluate loss: 0.2207
#   Evaluate AUROC: 0.7363, Evaluate AUPRC: 0.7738
#   Learning rate: 7.99e-05
#   Train set - Real:    0.492, Predict: 0.551
#   Evaluate set - Real: 0.543, Predict: 0.763
#   Save the best model, AUROC: 0.7363
# --------------------------------------------------
# Epoch [4/125]
#   Train loss: 0.1507, Evaluate loss: 0.1857
#   Evaluate AUROC: 0.7623, Evaluate AUPRC: 0.7961
#   Learning rate: 7.99e-05
#   Train set - Real:    0.492, Predict: 0.500
#   Evaluate set - Real: 0.543, Predict: 0.627
#   Save the best model, AUROC: 0.7623
# --------------------------------------------------
# Epoch [5/125]
#   Train loss: 0.1425, Evaluate loss: 0.2096
#   Evaluate AUROC: 0.7684, Evaluate AUPRC: 0.8008
#   Learning rate: 7.98e-05
#   Train set - Real:    0.492, Predict: 0.467
#   Evaluate set - Real: 0.543, Predict: 0.443
#   Save the best model, AUROC: 0.7684
# --------------------------------------------------
# Epoch [6/125]
#   Train loss: 0.1387, Evaluate loss: 0.1537
#   Evaluate AUROC: 0.7836, Evaluate AUPRC: 0.8120
#   Learning rate: 7.97e-05
#   Train set - Real:    0.492, Predict: 0.429
#   Evaluate set - Real: 0.543, Predict: 0.427
#   Save the best model, AUROC: 0.7836
# --------------------------------------------------
# Epoch [7/125]
#   Train loss: 0.1332, Evaluate loss: 0.1589
#   Evaluate AUROC: 0.7838, Evaluate AUPRC: 0.8151
#   Learning rate: 7.95e-05
#   Train set - Real:    0.492, Predict: 0.437
#   Evaluate set - Real: 0.543, Predict: 0.300
#   Save the best model, AUROC: 0.7838
# --------------------------------------------------
# Epoch [8/125]
#   Train loss: 0.1226, Evaluate loss: 0.1423
#   Evaluate AUROC: 0.7872, Evaluate AUPRC: 0.8185
#   Learning rate: 7.94e-05
#   Train set - Real:    0.492, Predict: 0.452
#   Evaluate set - Real: 0.543, Predict: 0.350
#   Save the best model, AUROC: 0.7872
# --------------------------------------------------
# Epoch [9/125]
#   Train loss: 0.1225, Evaluate loss: 0.1210
#   Evaluate AUROC: 0.7915, Evaluate AUPRC: 0.8229
#   Learning rate: 7.92e-05
#   Train set - Real:    0.492, Predict: 0.438
#   Evaluate set - Real: 0.543, Predict: 0.450
#   Save the best model, AUROC: 0.7915
# --------------------------------------------------
# Epoch [10/125]
#   Train loss: 0.1197, Evaluate loss: 0.1177
#   Evaluate AUROC: 0.7986, Evaluate AUPRC: 0.8309
#   Learning rate: 7.90e-05
#   Train set - Real:    0.492, Predict: 0.457
#   Evaluate set - Real: 0.543, Predict: 0.557
#   Save the best model, AUROC: 0.7986
# --------------------------------------------------
# Epoch [11/125]
#   Train loss: 0.1165, Evaluate loss: 0.1104
#   Evaluate AUROC: 0.8087, Evaluate AUPRC: 0.8403
#   Learning rate: 7.87e-05
#   Train set - Real:    0.492, Predict: 0.470
#   Evaluate set - Real: 0.543, Predict: 0.517
#   Save the best model, AUROC: 0.8087
# --------------------------------------------------
# Epoch [12/125]
#   Train loss: 0.1114, Evaluate loss: 0.1136
#   Evaluate AUROC: 0.8084, Evaluate AUPRC: 0.8407
#   Learning rate: 7.85e-05
#   Train set - Real:    0.492, Predict: 0.466
#   Evaluate set - Real: 0.543, Predict: 0.513
# --------------------------------------------------
# Epoch [13/125]
#   Train loss: 0.1119, Evaluate loss: 0.1097
#   Evaluate AUROC: 0.8062, Evaluate AUPRC: 0.8418
#   Learning rate: 7.82e-05
#   Train set - Real:    0.492, Predict: 0.460
#   Evaluate set - Real: 0.543, Predict: 0.503
# --------------------------------------------------
# Epoch [14/125]
#   Train loss: 0.1119, Evaluate loss: 0.1274
#   Evaluate AUROC: 0.8054, Evaluate AUPRC: 0.8391
#   Learning rate: 7.79e-05
#   Train set - Real:    0.492, Predict: 0.441
#   Evaluate set - Real: 0.543, Predict: 0.367
# --------------------------------------------------
# Epoch [15/125]
#   Train loss: 0.1094, Evaluate loss: 0.1217
#   Evaluate AUROC: 0.8035, Evaluate AUPRC: 0.8368
#   Learning rate: 7.76e-05
#   Train set - Real:    0.492, Predict: 0.454
#   Evaluate set - Real: 0.543, Predict: 0.417
# --------------------------------------------------
# Epoch [16/125]
#   Train loss: 0.1072, Evaluate loss: 0.1123
#   Evaluate AUROC: 0.8053, Evaluate AUPRC: 0.8428
#   Learning rate: 7.72e-05
#   Train set - Real:    0.492, Predict: 0.463
#   Evaluate set - Real: 0.543, Predict: 0.453
# --------------------------------------------------
# Epoch [17/125]
#   Train loss: 0.1055, Evaluate loss: 0.1175
#   Evaluate AUROC: 0.8036, Evaluate AUPRC: 0.8409
#   Learning rate: 7.68e-05
#   Train set - Real:    0.492, Predict: 0.465
#   Evaluate set - Real: 0.543, Predict: 0.430
# --------------------------------------------------
# Epoch [18/125]
#   Train loss: 0.1053, Evaluate loss: 0.1123
#   Evaluate AUROC: 0.8065, Evaluate AUPRC: 0.8445
#   Learning rate: 7.64e-05
#   Train set - Real:    0.492, Predict: 0.463
#   Evaluate set - Real: 0.543, Predict: 0.420
# --------------------------------------------------
# Epoch [19/125]
#   Train loss: 0.1056, Evaluate loss: 0.1071
#   Evaluate AUROC: 0.8038, Evaluate AUPRC: 0.8360
#   Learning rate: 7.60e-05
#   Train set - Real:    0.492, Predict: 0.462
#   Evaluate set - Real: 0.543, Predict: 0.517
# --------------------------------------------------
# Epoch [20/125]
#   Train loss: 0.1020, Evaluate loss: 0.1081
#   Evaluate AUROC: 0.8064, Evaluate AUPRC: 0.8401
#   Learning rate: 7.55e-05
#   Train set - Real:    0.492, Predict: 0.472
#   Evaluate set - Real: 0.543, Predict: 0.447
# --------------------------------------------------
# Epoch [21/125]
#   Train loss: 0.1016, Evaluate loss: 0.1054
#   Evaluate AUROC: 0.8103, Evaluate AUPRC: 0.8414
#   Learning rate: 7.51e-05
#   Train set - Real:    0.492, Predict: 0.487
#   Evaluate set - Real: 0.543, Predict: 0.523
#   Save the best model, AUROC: 0.8103
# --------------------------------------------------
# Epoch [22/125]
#   Train loss: 0.0980, Evaluate loss: 0.1092
#   Evaluate AUROC: 0.8091, Evaluate AUPRC: 0.8416
#   Learning rate: 7.46e-05
#   Train set - Real:    0.492, Predict: 0.482
#   Evaluate set - Real: 0.543, Predict: 0.443
# --------------------------------------------------
# Epoch [23/125]
#   Train loss: 0.1008, Evaluate loss: 0.1092
#   Evaluate AUROC: 0.8082, Evaluate AUPRC: 0.8377
#   Learning rate: 7.40e-05
#   Train set - Real:    0.492, Predict: 0.469
#   Evaluate set - Real: 0.543, Predict: 0.427
# --------------------------------------------------
# Epoch [24/125]
#   Train loss: 0.0981, Evaluate loss: 0.1028
#   Evaluate AUROC: 0.8117, Evaluate AUPRC: 0.8399
#   Learning rate: 7.35e-05
#   Train set - Real:    0.492, Predict: 0.475
#   Evaluate set - Real: 0.543, Predict: 0.533
#   Save the best model, AUROC: 0.8117
# --------------------------------------------------
# Epoch [25/125]
#   Train loss: 0.1065, Evaluate loss: 0.1002
#   Evaluate AUROC: 0.8110, Evaluate AUPRC: 0.8449
#   Learning rate: 7.30e-05
#   Train set - Real:    0.492, Predict: 0.502
#   Evaluate set - Real: 0.543, Predict: 0.600
# --------------------------------------------------
# Epoch [26/125]
#   Train loss: 0.0990, Evaluate loss: 0.1401
#   Evaluate AUROC: 0.8128, Evaluate AUPRC: 0.8441
#   Learning rate: 7.24e-05
#   Train set - Real:    0.492, Predict: 0.508
#   Evaluate set - Real: 0.543, Predict: 0.280
#   Save the best model, AUROC: 0.8128
# --------------------------------------------------
# Epoch [27/125]
#   Train loss: 0.0994, Evaluate loss: 0.1270
#   Evaluate AUROC: 0.8160, Evaluate AUPRC: 0.8451
#   Learning rate: 7.18e-05
#   Train set - Real:    0.492, Predict: 0.485
#   Evaluate set - Real: 0.543, Predict: 0.317
#   Save the best model, AUROC: 0.8160
# --------------------------------------------------
# Epoch [28/125]
#   Train loss: 0.0954, Evaluate loss: 0.1045
#   Evaluate AUROC: 0.8165, Evaluate AUPRC: 0.8480
#   Learning rate: 7.11e-05
#   Train set - Real:    0.492, Predict: 0.512
#   Evaluate set - Real: 0.543, Predict: 0.663
#   Save the best model, AUROC: 0.8165
# --------------------------------------------------
# Epoch [29/125]
#   Train loss: 0.0935, Evaluate loss: 0.1089
#   Evaluate AUROC: 0.8132, Evaluate AUPRC: 0.8441
#   Learning rate: 7.05e-05
#   Train set - Real:    0.492, Predict: 0.493
#   Evaluate set - Real: 0.543, Predict: 0.447
# --------------------------------------------------
# Epoch [30/125]
#   Train loss: 0.0919, Evaluate loss: 0.1044
#   Evaluate AUROC: 0.8149, Evaluate AUPRC: 0.8479
#   Learning rate: 6.99e-05
#   Train set - Real:    0.492, Predict: 0.509
#   Evaluate set - Real: 0.543, Predict: 0.633
# --------------------------------------------------
# Epoch [31/125]
#   Train loss: 0.0927, Evaluate loss: 0.1098
#   Evaluate AUROC: 0.8178, Evaluate AUPRC: 0.8491
#   Learning rate: 6.92e-05
#   Train set - Real:    0.492, Predict: 0.504
#   Evaluate set - Real: 0.543, Predict: 0.473
#   Save the best model, AUROC: 0.8178
# --------------------------------------------------
# Epoch [32/125]
#   Train loss: 0.0903, Evaluate loss: 0.1261
#   Evaluate AUROC: 0.8202, Evaluate AUPRC: 0.8496
#   Learning rate: 6.85e-05
#   Train set - Real:    0.492, Predict: 0.507
#   Evaluate set - Real: 0.543, Predict: 0.307
#   Save the best model, AUROC: 0.8202
# --------------------------------------------------
# Epoch [33/125]
#   Train loss: 0.0871, Evaluate loss: 0.1041
#   Evaluate AUROC: 0.8198, Evaluate AUPRC: 0.8492
#   Learning rate: 6.78e-05
#   Train set - Real:    0.492, Predict: 0.495
#   Evaluate set - Real: 0.543, Predict: 0.460
# --------------------------------------------------
# Epoch [34/125]
#   Train loss: 0.0896, Evaluate loss: 0.1068
#   Evaluate AUROC: 0.8169, Evaluate AUPRC: 0.8468
#   Learning rate: 6.70e-05
#   Train set - Real:    0.492, Predict: 0.507
#   Evaluate set - Real: 0.543, Predict: 0.537
# --------------------------------------------------
# Epoch [35/125]
#   Train loss: 0.0869, Evaluate loss: 0.1094
#   Evaluate AUROC: 0.8233, Evaluate AUPRC: 0.8525
#   Learning rate: 6.63e-05
#   Train set - Real:    0.492, Predict: 0.487
#   Evaluate set - Real: 0.543, Predict: 0.407
#   Save the best model, AUROC: 0.8233
# --------------------------------------------------
# Epoch [36/125]
#   Train loss: 0.0876, Evaluate loss: 0.1054
#   Evaluate AUROC: 0.8173, Evaluate AUPRC: 0.8506
#   Learning rate: 6.55e-05
#   Train set - Real:    0.492, Predict: 0.504
#   Evaluate set - Real: 0.543, Predict: 0.563
# --------------------------------------------------
# Epoch [37/125]
#   Train loss: 0.0854, Evaluate loss: 0.1484
#   Evaluate AUROC: 0.8207, Evaluate AUPRC: 0.8485
#   Learning rate: 6.47e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.200
# --------------------------------------------------
# Epoch [38/125]
#   Train loss: 0.0874, Evaluate loss: 0.1123
#   Evaluate AUROC: 0.8206, Evaluate AUPRC: 0.8507
#   Learning rate: 6.39e-05
#   Train set - Real:    0.492, Predict: 0.514
#   Evaluate set - Real: 0.543, Predict: 0.350
# --------------------------------------------------
# Epoch [39/125]
#   Train loss: 0.0839, Evaluate loss: 0.1280
#   Evaluate AUROC: 0.8209, Evaluate AUPRC: 0.8519
#   Learning rate: 6.31e-05
#   Train set - Real:    0.492, Predict: 0.495
#   Evaluate set - Real: 0.543, Predict: 0.307
# --------------------------------------------------
# Epoch [40/125]
#   Train loss: 0.0809, Evaluate loss: 0.1199
#   Evaluate AUROC: 0.8246, Evaluate AUPRC: 0.8565
#   Learning rate: 6.23e-05
#   Train set - Real:    0.492, Predict: 0.504
#   Evaluate set - Real: 0.543, Predict: 0.373
#   Save the best model, AUROC: 0.8246
# --------------------------------------------------
# Epoch [41/125]
#   Train loss: 0.0820, Evaluate loss: 0.1094
#   Evaluate AUROC: 0.8181, Evaluate AUPRC: 0.8516
#   Learning rate: 6.15e-05
#   Train set - Real:    0.492, Predict: 0.508
#   Evaluate set - Real: 0.543, Predict: 0.627
# --------------------------------------------------
# Epoch [42/125]
#   Train loss: 0.0768, Evaluate loss: 0.1099
#   Evaluate AUROC: 0.8192, Evaluate AUPRC: 0.8524
#   Learning rate: 6.06e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.600
# --------------------------------------------------
# Epoch [43/125]
#   Train loss: 0.0791, Evaluate loss: 0.1514
#   Evaluate AUROC: 0.8273, Evaluate AUPRC: 0.8565
#   Learning rate: 5.97e-05
#   Train set - Real:    0.492, Predict: 0.502
#   Evaluate set - Real: 0.543, Predict: 0.337
#   Save the best model, AUROC: 0.8273
# --------------------------------------------------
# Epoch [44/125]
#   Train loss: 0.0762, Evaluate loss: 0.1160
#   Evaluate AUROC: 0.8240, Evaluate AUPRC: 0.8555
#   Learning rate: 5.89e-05
#   Train set - Real:    0.492, Predict: 0.515
#   Evaluate set - Real: 0.543, Predict: 0.597
# --------------------------------------------------
# Epoch [45/125]
#   Train loss: 0.0767, Evaluate loss: 0.1133
#   Evaluate AUROC: 0.8283, Evaluate AUPRC: 0.8608
#   Learning rate: 5.80e-05
#   Train set - Real:    0.492, Predict: 0.507
#   Evaluate set - Real: 0.543, Predict: 0.580
#   Save the best model, AUROC: 0.8283
# --------------------------------------------------
# Epoch [46/125]
#   Train loss: 0.0769, Evaluate loss: 0.1147
#   Evaluate AUROC: 0.8337, Evaluate AUPRC: 0.8644
#   Learning rate: 5.71e-05
#   Train set - Real:    0.492, Predict: 0.498
#   Evaluate set - Real: 0.543, Predict: 0.420
#   Save the best model, AUROC: 0.8337
# --------------------------------------------------
# Epoch [47/125]
#   Train loss: 0.0760, Evaluate loss: 0.1180
#   Evaluate AUROC: 0.8346, Evaluate AUPRC: 0.8650
#   Learning rate: 5.61e-05
#   Train set - Real:    0.492, Predict: 0.510
#   Evaluate set - Real: 0.543, Predict: 0.453
#   Save the best model, AUROC: 0.8346
# --------------------------------------------------
# Epoch [48/125]
#   Train loss: 0.0731, Evaluate loss: 0.1097
#   Evaluate AUROC: 0.8320, Evaluate AUPRC: 0.8630
#   Learning rate: 5.52e-05
#   Train set - Real:    0.492, Predict: 0.513
#   Evaluate set - Real: 0.543, Predict: 0.597
# --------------------------------------------------
# Epoch [49/125]
#   Train loss: 0.0713, Evaluate loss: 0.1281
#   Evaluate AUROC: 0.8376, Evaluate AUPRC: 0.8667
#   Learning rate: 5.43e-05
#   Train set - Real:    0.492, Predict: 0.530
#   Evaluate set - Real: 0.543, Predict: 0.383
#   Save the best model, AUROC: 0.8376
# --------------------------------------------------
# Epoch [50/125]
#   Train loss: 0.0775, Evaluate loss: 0.1146
#   Evaluate AUROC: 0.8340, Evaluate AUPRC: 0.8632
#   Learning rate: 5.33e-05
#   Train set - Real:    0.492, Predict: 0.487
#   Evaluate set - Real: 0.543, Predict: 0.480
# --------------------------------------------------
# Epoch [51/125]
#   Train loss: 0.0750, Evaluate loss: 0.1270
#   Evaluate AUROC: 0.8350, Evaluate AUPRC: 0.8643
#   Learning rate: 5.24e-05
#   Train set - Real:    0.492, Predict: 0.510
#   Evaluate set - Real: 0.543, Predict: 0.390
# --------------------------------------------------
# Epoch [52/125]
#   Train loss: 0.0709, Evaluate loss: 0.1445
#   Evaluate AUROC: 0.8381, Evaluate AUPRC: 0.8667
#   Learning rate: 5.14e-05
#   Train set - Real:    0.492, Predict: 0.517
#   Evaluate set - Real: 0.543, Predict: 0.383
#   Save the best model, AUROC: 0.8381
# --------------------------------------------------
# Epoch [53/125]
#   Train loss: 0.0715, Evaluate loss: 0.1147
#   Evaluate AUROC: 0.8325, Evaluate AUPRC: 0.8632
#   Learning rate: 5.05e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.600
# --------------------------------------------------
# Epoch [54/125]
#   Train loss: 0.0700, Evaluate loss: 0.1183
#   Evaluate AUROC: 0.8371, Evaluate AUPRC: 0.8679
#   Learning rate: 4.95e-05
#   Train set - Real:    0.492, Predict: 0.515
#   Evaluate set - Real: 0.543, Predict: 0.517
# --------------------------------------------------
# Epoch [55/125]
#   Train loss: 0.0662, Evaluate loss: 0.1309
#   Evaluate AUROC: 0.8387, Evaluate AUPRC: 0.8693
#   Learning rate: 4.85e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.537
#   Save the best model, AUROC: 0.8387
# --------------------------------------------------
# Epoch [56/125]
#   Train loss: 0.0695, Evaluate loss: 0.1219
#   Evaluate AUROC: 0.8388, Evaluate AUPRC: 0.8695
#   Learning rate: 4.75e-05
#   Train set - Real:    0.492, Predict: 0.508
#   Evaluate set - Real: 0.543, Predict: 0.523
#   Save the best model, AUROC: 0.8388
# --------------------------------------------------
# Epoch [57/125]
#   Train loss: 0.0677, Evaluate loss: 0.1268
#   Evaluate AUROC: 0.8404, Evaluate AUPRC: 0.8701
#   Learning rate: 4.65e-05
#   Train set - Real:    0.492, Predict: 0.500
#   Evaluate set - Real: 0.543, Predict: 0.470
#   Save the best model, AUROC: 0.8404
# --------------------------------------------------
# Epoch [58/125]
#   Train loss: 0.0689, Evaluate loss: 0.1299
#   Evaluate AUROC: 0.8377, Evaluate AUPRC: 0.8690
#   Learning rate: 4.56e-05
#   Train set - Real:    0.492, Predict: 0.487
#   Evaluate set - Real: 0.543, Predict: 0.560
# --------------------------------------------------
# Epoch [59/125]
#   Train loss: 0.0678, Evaluate loss: 0.1288
#   Evaluate AUROC: 0.8370, Evaluate AUPRC: 0.8686
#   Learning rate: 4.46e-05
#   Train set - Real:    0.492, Predict: 0.521
#   Evaluate set - Real: 0.543, Predict: 0.597
# --------------------------------------------------
# Epoch [60/125]
#   Train loss: 0.0665, Evaluate loss: 0.1263
#   Evaluate AUROC: 0.8350, Evaluate AUPRC: 0.8678
#   Learning rate: 4.36e-05
#   Train set - Real:    0.492, Predict: 0.495
#   Evaluate set - Real: 0.543, Predict: 0.637
# --------------------------------------------------
# Epoch [61/125]
#   Train loss: 0.0691, Evaluate loss: 0.1432
#   Evaluate AUROC: 0.8370, Evaluate AUPRC: 0.8687
#   Learning rate: 4.26e-05
#   Train set - Real:    0.492, Predict: 0.519
#   Evaluate set - Real: 0.543, Predict: 0.570
# --------------------------------------------------
# Epoch [62/125]
#   Train loss: 0.0653, Evaluate loss: 0.1337
#   Evaluate AUROC: 0.8412, Evaluate AUPRC: 0.8725
#   Learning rate: 4.16e-05
#   Train set - Real:    0.492, Predict: 0.508
#   Evaluate set - Real: 0.543, Predict: 0.507
#   Save the best model, AUROC: 0.8412
# --------------------------------------------------
# Epoch [63/125]
#   Train loss: 0.0650, Evaluate loss: 0.1387
#   Evaluate AUROC: 0.8430, Evaluate AUPRC: 0.8740
#   Learning rate: 4.06e-05
#   Train set - Real:    0.492, Predict: 0.512
#   Evaluate set - Real: 0.543, Predict: 0.510
#   Save the best model, AUROC: 0.8430
# --------------------------------------------------
# Epoch [64/125]
#   Train loss: 0.0679, Evaluate loss: 0.1569
#   Evaluate AUROC: 0.8446, Evaluate AUPRC: 0.8738
#   Learning rate: 3.95e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.370
#   Save the best model, AUROC: 0.8446
# --------------------------------------------------
# Epoch [65/125]
#   Train loss: 0.0634, Evaluate loss: 0.1290
#   Evaluate AUROC: 0.8408, Evaluate AUPRC: 0.8732
#   Learning rate: 3.85e-05
#   Train set - Real:    0.492, Predict: 0.506
#   Evaluate set - Real: 0.543, Predict: 0.587
# --------------------------------------------------
# Epoch [66/125]
#   Train loss: 0.0620, Evaluate loss: 0.1310
#   Evaluate AUROC: 0.8471, Evaluate AUPRC: 0.8766
#   Learning rate: 3.75e-05
#   Train set - Real:    0.492, Predict: 0.498
#   Evaluate set - Real: 0.543, Predict: 0.477
#   Save the best model, AUROC: 0.8471
# --------------------------------------------------
# Epoch [67/125]
#   Train loss: 0.0630, Evaluate loss: 0.1287
#   Evaluate AUROC: 0.8434, Evaluate AUPRC: 0.8751
#   Learning rate: 3.65e-05
#   Train set - Real:    0.492, Predict: 0.498
#   Evaluate set - Real: 0.543, Predict: 0.560
# --------------------------------------------------
# Epoch [68/125]
#   Train loss: 0.0611, Evaluate loss: 0.1493
#   Evaluate AUROC: 0.8442, Evaluate AUPRC: 0.8755
#   Learning rate: 3.55e-05
#   Train set - Real:    0.492, Predict: 0.510
#   Evaluate set - Real: 0.543, Predict: 0.560
# --------------------------------------------------
# Epoch [69/125]
#   Train loss: 0.0646, Evaluate loss: 0.1344
#   Evaluate AUROC: 0.8429, Evaluate AUPRC: 0.8751
#   Learning rate: 3.45e-05
#   Train set - Real:    0.492, Predict: 0.503
#   Evaluate set - Real: 0.543, Predict: 0.610
# --------------------------------------------------
# Epoch [70/125]
#   Train loss: 0.0639, Evaluate loss: 0.1378
#   Evaluate AUROC: 0.8463, Evaluate AUPRC: 0.8768
#   Learning rate: 3.36e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.513
# --------------------------------------------------
# Epoch [71/125]
#   Train loss: 0.0644, Evaluate loss: 0.1276
#   Evaluate AUROC: 0.8444, Evaluate AUPRC: 0.8758
#   Learning rate: 3.26e-05
#   Train set - Real:    0.492, Predict: 0.507
#   Evaluate set - Real: 0.543, Predict: 0.537
# --------------------------------------------------
# Epoch [72/125]
#   Train loss: 0.0654, Evaluate loss: 0.1265
#   Evaluate AUROC: 0.8469, Evaluate AUPRC: 0.8770
#   Learning rate: 3.16e-05
#   Train set - Real:    0.492, Predict: 0.503
#   Evaluate set - Real: 0.543, Predict: 0.540
# --------------------------------------------------
# Epoch [73/125]
#   Train loss: 0.0589, Evaluate loss: 0.1372
#   Evaluate AUROC: 0.8443, Evaluate AUPRC: 0.8755
#   Learning rate: 3.06e-05
#   Train set - Real:    0.492, Predict: 0.517
#   Evaluate set - Real: 0.543, Predict: 0.587
# --------------------------------------------------
# Epoch [74/125]
#   Train loss: 0.0609, Evaluate loss: 0.1446
#   Evaluate AUROC: 0.8449, Evaluate AUPRC: 0.8762
#   Learning rate: 2.96e-05
#   Train set - Real:    0.492, Predict: 0.511
#   Evaluate set - Real: 0.543, Predict: 0.597
# --------------------------------------------------
# Epoch [75/125]
#   Train loss: 0.0597, Evaluate loss: 0.1360
#   Evaluate AUROC: 0.8449, Evaluate AUPRC: 0.8756
#   Learning rate: 2.87e-05
#   Train set - Real:    0.492, Predict: 0.500
#   Evaluate set - Real: 0.543, Predict: 0.587
# --------------------------------------------------
# Epoch [76/125]
#   Train loss: 0.0591, Evaluate loss: 0.1385
#   Evaluate AUROC: 0.8446, Evaluate AUPRC: 0.8755
#   Learning rate: 2.77e-05
#   Train set - Real:    0.492, Predict: 0.503
#   Evaluate set - Real: 0.543, Predict: 0.597
# --------------------------------------------------
# Epoch [77/125]
#   Train loss: 0.0578, Evaluate loss: 0.1482
#   Evaluate AUROC: 0.8491, Evaluate AUPRC: 0.8789
#   Learning rate: 2.68e-05
#   Train set - Real:    0.492, Predict: 0.500
#   Evaluate set - Real: 0.543, Predict: 0.443
#   Save the best model, AUROC: 0.8491
# --------------------------------------------------
# Epoch [78/125]
#   Train loss: 0.0618, Evaluate loss: 0.1354
#   Evaluate AUROC: 0.8427, Evaluate AUPRC: 0.8748
#   Learning rate: 2.58e-05
#   Train set - Real:    0.492, Predict: 0.498
#   Evaluate set - Real: 0.543, Predict: 0.603
# --------------------------------------------------
# Epoch [79/125]
#   Train loss: 0.0611, Evaluate loss: 0.1403
#   Evaluate AUROC: 0.8440, Evaluate AUPRC: 0.8760
#   Learning rate: 2.49e-05
#   Train set - Real:    0.492, Predict: 0.500
#   Evaluate set - Real: 0.543, Predict: 0.570
# --------------------------------------------------
# Epoch [80/125]
#   Train loss: 0.0605, Evaluate loss: 0.1374
#   Evaluate AUROC: 0.8451, Evaluate AUPRC: 0.8766
#   Learning rate: 2.40e-05
#   Train set - Real:    0.492, Predict: 0.496
#   Evaluate set - Real: 0.543, Predict: 0.547
# --------------------------------------------------
# Epoch [81/125]
#   Train loss: 0.0571, Evaluate loss: 0.1641
#   Evaluate AUROC: 0.8428, Evaluate AUPRC: 0.8749
#   Learning rate: 2.30e-05
#   Train set - Real:    0.492, Predict: 0.497
#   Evaluate set - Real: 0.543, Predict: 0.627
# --------------------------------------------------
# Epoch [82/125]
#   Train loss: 0.0635, Evaluate loss: 0.1465
#   Evaluate AUROC: 0.8450, Evaluate AUPRC: 0.8763
#   Learning rate: 2.21e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.577
# --------------------------------------------------
# Epoch [83/125]
#   Train loss: 0.0599, Evaluate loss: 0.1456
#   Evaluate AUROC: 0.8457, Evaluate AUPRC: 0.8766
#   Learning rate: 2.12e-05
#   Train set - Real:    0.492, Predict: 0.508
#   Evaluate set - Real: 0.543, Predict: 0.520
# --------------------------------------------------
# Epoch [84/125]
#   Train loss: 0.0603, Evaluate loss: 0.1477
#   Evaluate AUROC: 0.8468, Evaluate AUPRC: 0.8775
#   Learning rate: 2.04e-05
#   Train set - Real:    0.492, Predict: 0.503
#   Evaluate set - Real: 0.543, Predict: 0.520
# --------------------------------------------------
# Epoch [85/125]
#   Train loss: 0.0593, Evaluate loss: 0.1428
#   Evaluate AUROC: 0.8448, Evaluate AUPRC: 0.8764
#   Learning rate: 1.95e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.577
# --------------------------------------------------
# Epoch [86/125]
#   Train loss: 0.0562, Evaluate loss: 0.1548
#   Evaluate AUROC: 0.8446, Evaluate AUPRC: 0.8762
#   Learning rate: 1.86e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.623
# --------------------------------------------------
# Epoch [87/125]
#   Train loss: 0.0585, Evaluate loss: 0.1525
#   Evaluate AUROC: 0.8445, Evaluate AUPRC: 0.8762
#   Learning rate: 1.78e-05
#   Train set - Real:    0.492, Predict: 0.501
#   Evaluate set - Real: 0.543, Predict: 0.590
# --------------------------------------------------
# Epoch [88/125]
#   Train loss: 0.0574, Evaluate loss: 0.1517
#   Evaluate AUROC: 0.8477, Evaluate AUPRC: 0.8781
#   Learning rate: 1.70e-05
#   Train set - Real:    0.492, Predict: 0.505
#   Evaluate set - Real: 0.543, Predict: 0.520
# --------------------------------------------------
# Epoch [89/125]
#   Train loss: 0.0602, Evaluate loss: 0.1510
#   Evaluate AUROC: 0.8450, Evaluate AUPRC: 0.8767
#   Learning rate: 1.62e-05
#   Train set - Real:    0.492, Predict: 0.497
#   Evaluate set - Real: 0.543, Predict: 0.607
# --------------------------------------------------
# Epoch [90/125]
#   Train loss: 0.0584, Evaluate loss: 0.1479
#   Evaluate AUROC: 0.8466, Evaluate AUPRC: 0.8772
#   Learning rate: 1.54e-05
#   Train set - Real:    0.492, Predict: 0.510
#   Evaluate set - Real: 0.543, Predict: 0.540
# --------------------------------------------------
# Epoch [91/125]
#   Train loss: 0.0586, Evaluate loss: 0.1465
#   Evaluate AUROC: 0.8464, Evaluate AUPRC: 0.8771
#   Learning rate: 1.46e-05
#   Train set - Real:    0.492, Predict: 0.495
#   Evaluate set - Real: 0.543, Predict: 0.557
# --------------------------------------------------
# Epoch [92/125]
#   Train loss: 0.0571, Evaluate loss: 0.1542
#   Evaluate AUROC: 0.8444, Evaluate AUPRC: 0.8762
#   Learning rate: 1.38e-05
#   Train set - Real:    0.492, Predict: 0.495
#   Evaluate set - Real: 0.543, Predict: 0.633
#
# Early stopping occurred at the 92th epoch.
#
# Best evaluate AUROC: 0.8491

# %%
# Load the best model for testing
model.load_state_dict(torch.load(config.model_save_path))
print("Load the best model for testing...")

# Carry out the test
print("\nTesting start...")
test_results = comprehensive_test(model, test_loader, device)
# Out:
# Load the best model for testing...
#
# Testing start...
#
# Performance of the test set (threshold=0.45):
# AUROC:       0.8759
# AUPRC:       0.8911
# Accuracy:    0.8133
# Precision:   0.8389
# Sensitivity: 0.7962
# F1-Score:    0.8170
# Specificity: 0.8322
# MCC:         0.6277

# %%
# Save metrics to CSV
save_metrics_to_csv(test_results['all_metrics'], config.metrics_save_path)

# Generate all plots
print("Generating plots...")

# Training curves
print("Plotting training curves...")
plot_training_curves(
    results['train_losses'], 
    results['val_losses'], 
    results['val_aurocs'],
    results['val_auprcs'],
    os.path.join(config.plots_save_dir, 'training_curves.png')
)

# ROC curve
print("Plotting ROC curve...")
plot_roc_curve(
    test_results['labels'],
    test_results['predictions'],
    os.path.join(config.plots_save_dir, 'roc_curve.png')
)

# PR curve
print("Plotting PR curve...")
plot_pr_curve(
    test_results['labels'],
    test_results['predictions'],
    os.path.join(config.plots_save_dir, 'pr_curve.png')
)

# Confusion matrix
print("Plotting confusion matrix...")
plot_confusion_matrix(
    test_results['labels'],
    test_results['predictions'],
    test_results['best_threshold'],
    os.path.join(config.plots_save_dir, 'confusion_matrix.png')
)

# Probability distribution
print("Plotting probability distribution...")
plot_probability_distribution(
    test_results['labels'],
    test_results['predictions'],
    test_results['best_threshold'],
    os.path.join(config.plots_save_dir, 'probability_distribution.png')
)

print("All tasks completed successfully!")
# Out:
# Metrics saved to HNRNPC/Output/metrics.csv
# Generating plots...
# Plotting training curves...
# Plotting ROC curve...
# Plotting PR curve...
# Plotting confusion matrix...
# Plotting probability distribution...
# All tasks completed successfully!
